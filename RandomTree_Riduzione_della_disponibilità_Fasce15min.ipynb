# %% [markdown]
# <a href="https://colab.research.google.com/github/DecioVdA/ProveComm/blob/main/RandomTree_Riduzione_della_disponibilit%C3%A0_Fasce15min.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
